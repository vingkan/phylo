# %%
import os 
import numpy as np
import pandas as pd
import scipy
import imageio
import math
import phylo

from sklearn import decomposition
from sklearn import datasets

from PIL import Image

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks")
plt.style.use("seaborn-whitegrid")

# %%
# %load_ext blackcellmagic
# Out:
# The blackcellmagic extension is already loaded. To reload it, use:
#   %reload_ext blackcellmagic

# %%
REGULAR_POKEMON = phylo.vectorize_pokemon(phylo.REGULAR_POKEMON_PATH)
SHINY_POKEMON = phylo.vectorize_pokemon(phylo.SHINY_POKEMON_PATH)
# Out:
# Vectorizing pokemon from /Users/rchatrath/workspace/phylo/images/regular/
# Vector iteration 0
# Vector iteration 100
# Vector iteration 200
# Vector iteration 300
# Vector iteration 400
# Vector iteration 500
# Vector iteration 600
# Done vectorizing
# Vectorizing pokemon from /Users/rchatrath/workspace/phylo/images/shiny/
# Vector iteration 0
# Vector iteration 100
# Vector iteration 200
# Vector iteration 300
# Vector iteration 400
# Vector iteration 500
# Vector iteration 600
# Done vectorizing

# %%
pca = decomposition.PCA(n_components=2)
pca.fit(REGULAR_POKEMON)
X = pca.transform(REGULAR_POKEMON)

# %%
print(X)
# Out:
# [[ 33.9225445   26.58784047]
#  [-24.32651835   2.07606856]
#  [ -0.21858195   5.72127142]
#  ...
#  [-11.03951983 -31.08706538]
#  [-22.24009154  -2.4045373 ]
#  [ 34.61863732 -25.5170876 ]]

# %%
print(pca.components_[0][6657])
print(pca.components_[1][6657])
# Out:
# 0.027164156554177442
# -0.0023321204745019855

# %%
ddf = pd.DataFrame() 
ddf["x"] = pd.Series([x[0] for x in X])
ddf["y"] = pd.Series([x[1] for x in X])

# %%
sns.scatterplot(x="x", y="y", data=ddf)
